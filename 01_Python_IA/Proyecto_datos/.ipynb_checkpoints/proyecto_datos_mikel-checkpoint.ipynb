# %% [markdown]
# # PART 1: Electric Vehicle population in the state of Washington (WA)
#
# ## Descripción
#
# This dataset shows the Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs) that are currently registered through Washington State Department of Licensing (DOL).
#
# ### Fuente
#
# data.gov
#
# ## Objetivo
#
# Sacar conclusiones interesantes sobre la población de vehiculos electricos en el estado de Washington mediante estadísticas y visualizaciones
#
# ## Importando librerias

# %%
import numpy as np
import pandas as pd 
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Cargando el dataset

# %%
link = 'https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD'

df = pd.read_csv(link, sep= ',', nrows=100_000)

df.head()
# Out:
#    VIN (1-10)    County     City State  Postal Code  Model Year    Make
# 0  5YJXCAE26J    Yakima   Yakima    WA      98908.0        2018   TESLA  \
# 1  JHMZC5F37M    Kitsap  Poulsbo    WA      98370.0        2021   HONDA
# 2  5YJ3E1EB0K      King  Seattle    WA      98199.0        2019   TESLA
# 3  1N4AZ0CP5D      King  Seattle    WA      98119.0        2013  NISSAN
# 4  5YJSA1E21H  Thurston    Lacey    WA      98516.0        2017   TESLA
#
#      Model                   Electric Vehicle Type
# 0  MODEL X          Battery Electric Vehicle (BEV)  \
# 1  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  MODEL 3          Battery Electric Vehicle (BEV)
# 3     LEAF          Battery Electric Vehicle (BEV)
# 4  MODEL S          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range
# 0           Clean Alternative Fuel Vehicle Eligible             238  \
# 1           Clean Alternative Fuel Vehicle Eligible              47
# 2           Clean Alternative Fuel Vehicle Eligible             220
# 3           Clean Alternative Fuel Vehicle Eligible              75
# 4           Clean Alternative Fuel Vehicle Eligible             210
#
#    Base MSRP  Legislative District  DOL Vehicle ID
# 0          0                  14.0       141151601  \
# 1          0                  23.0       171566447
# 2          0                  36.0         9426525
# 3          0                  36.0       211807760
# 4          0                  22.0       185810306
#
#               Vehicle Location                              Electric Utility
# 0  POINT (-120.56916 46.58514)                                    PACIFICORP  \
# 1  POINT (-122.64681 47.73689)                        PUGET SOUND ENERGY INC
# 2  POINT (-122.40092 47.65908)  CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 3   POINT (-122.3684 47.64586)  CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 4  POINT (-122.75379 47.06316)                        PUGET SOUND ENERGY INC
#
#    2020 Census Tract
# 0       5.307700e+10
# 1       5.303509e+10
# 2       5.303301e+10
# 3       5.303301e+10
# 4       5.306701e+10

# %% [markdown]
# ## Exploración inicial
#
# Con el objetivo de hacer un primer vistazo y filtrado de datos

# %%
df.info() # se ven muy pocos valores nulos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         100000 non-null  object
#  1   County                                             99998 non-null   object
#  2   City                                               99998 non-null   object
#  3   State                                              100000 non-null  object
#  4   Postal Code                                        99998 non-null   float64
#  5   Model Year                                         100000 non-null  int64
#  6   Make                                               100000 non-null  object
#  7   Model                                              99817 non-null   object
#  8   Electric Vehicle Type                              100000 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  100000 non-null  object
#  10  Electric Range                                     100000 non-null  int64
#  11  Base MSRP                                          100000 non-null  int64
#  12  Legislative District                               99941 non-null   float64
#  13  DOL Vehicle ID                                     100000 non-null  int64
#  14  Vehicle Location                                   99989 non-null   object
#  15  Electric Utility                                   99998 non-null   object
#  16  2020 Census Tract                                  99998 non-null   float64
# dtypes: float64(3), int64(4), object(10)
# memory usage: 13.0+ MB

# %%
print(df['State'].unique())
print('\n')

print(df['County'].unique())
print('\n')

print(df['City'].unique())
print('\n')
# Out:
# ['WA' 'AP' 'BC' 'KY' 'NE' 'PA' 'AZ' 'IL' 'DC' 'MD' 'VA' 'NV' 'CA' 'OR'
#  'TX' 'NC' 'WY' 'AL' 'GA' 'MO' 'NY']
#
#
# ['Yakima' 'Kitsap' 'King' 'Thurston' 'Snohomish' 'Chelan' 'Skagit'
#  'Spokane' 'Whitman' 'Stevens' 'Douglas' 'Island' nan 'Walla Walla'
#  'Clark' 'Klickitat' 'Cowlitz' 'Jefferson' 'Clallam' 'Pierce' 'Whatcom'
#  'San Juan' 'Mason' 'Okanogan' 'Kittitas' 'Grant' 'Benton' 'Franklin'
#  'Grays Harbor' 'Lewis' 'Oldham' 'Skamania' 'Pend Oreille' 'Asotin'
#  'Pacific' 'Montgomery' 'Maricopa' 'Wahkiakum' 'Lake' 'Adams'
#  'District of Columbia' 'Anne Arundel' 'Goochland' 'Lincoln' 'Orange'
#  'Columbia' 'Kern' 'Marin' 'Polk' 'Ferry' 'Bexar' 'Hoke' 'Laramie'
#  'Contra Costa' 'Lee' 'DeKalb' 'Platte' 'Cumberland' 'Garfield' 'Loudoun'
#  'San Diego' 'Saratoga' 'Los Angeles' 'Santa Cruz' 'El Paso' 'Santa Clara'
#  'Denton' 'Frederick' 'Wayne' 'Riverside' 'Fairfax' 'Multnomah'
#  'Sacramento' 'Carroll' 'Wichita']
#
#
# ['Yakima' 'Poulsbo' 'Seattle' 'Lacey' 'Olympia' 'Tumwater' 'Rochester'
#  'Bremerton' 'Bainbridge Island' 'Everett' 'Leavenworth' 'Mill Creek'
#  'Snohomish' 'Mount Vernon' 'Arlington' 'Lake Stevens' 'Burlington'
#  'Anacortes' 'Edmonds' 'Bothell' 'Sultan' 'Spokane' 'Pullman' 'Yelm'
#  'Port Orchard' 'Palouse' 'Monroe' 'Marysville' 'Mukilteo' 'Brier'
#  'Lynnwood' 'Kettle Falls' 'Orondo' 'Selah' 'Oak Harbor' 'Clinton'
#  'Cheney' 'Granite Falls' 'Renton' nan 'Walla Walla' 'Freeland' 'Kent'
#  'Redmond' 'Vancouver' 'Tukwila' 'Federal Way' 'Kirkland' 'Bellevue'
#  'Battle Ground' 'Duvall' 'Brush Prairie' 'Sammamish' 'Burien' 'Auburn'
#  'Bingen' 'Camas' 'Issaquah' 'Shoreline' 'Covington' 'Woodinville'
#  'Longview' 'Olalla' 'Normandy Park' 'Port Townsend' 'North Bend'
#  'Seabeck' 'Medina' 'Maple Valley' 'Newcastle' 'Des Moines' 'Ridgefield'
#  'Washougal' 'Kelso' 'Kenmore' 'Nine Mile Falls' 'Moxee' 'Seatac'
#  'La Center' 'Lake Forest Park' 'Sunnyside' 'Kalama' 'Grandview' 'Sequim'
#  'Beaux Arts' 'Silverdale' 'Quilcene' 'Woodland' 'Indianola'
#  'Camano Island' 'Keyport' 'Tieton' 'Brinnon' 'Mercer Island'
#  'Black Diamond' 'Port Hadlock' 'Rainier' 'Kingston' 'Suquamish'
#  'Castle Rock' 'Clyde Hill' 'Port Ludlow' 'Enumclaw' 'Tenino' 'Goldendale'
#  'Coupeville' 'Nordland' 'White Salmon' 'Silverlake' 'Ariel' 'Mabton'
#  'Pacific' 'Yacolt' 'Woodway' 'Zillah' 'Toutle' 'Port Angeles' 'Ryderwood'
#  'Algona' 'Bucoda' 'Stanwood' 'Wapato' 'Tulalip' 'Forks' 'Amboy' 'Granger'
#  'Toppenish' 'Carrolls' 'Mountlake Terrace' 'Langley' 'Colville' 'Milton'
#  'Naches' 'Snoqualmie' 'Chewelah' 'Hunts Point' 'Yarrow Point' 'Gold Bar'
#  'Centralia' 'Chimacum' 'Carnation' 'Hansville' 'Skykomish' 'Darrington'
#  'Gig Harbor' 'Union Gap' 'Index' 'Deer Park' 'Lakewood' 'Tacoma'
#  'Bellingham' 'Olga' 'Allyn' 'South Hill' 'Wenatchee' 'Fircrest'
#  'Valleyford' 'Methow' 'Lynden' 'Puyallup' 'Anderson Island' 'Cle Elum'
#  'Moses Lake' 'Omak' 'Spokane Valley' 'Fife' 'Vashon' 'Shelton' 'Richland'
#  'Pasco' 'Orting' 'Kennewick' 'Joint Base Lewis Mcchord' 'East Wenatchee'
#  'Ocean Shores' 'Manson' 'Royal City' 'Snowden' 'College Place' 'Prosser'
#  'Sumner' 'Goshen' 'Ellensburg' 'Belfair' 'Trout Lake' 'Carson' 'Elma'
#  'Hoodsport' 'Edgewood' 'Eastsound' 'Chelan' 'Eatonville' 'Entiat'
#  'Friday Harbor' 'Fall City' 'Sedro Woolley' 'Bonney Lake' 'Mccleary'
#  'Veradale' 'Randle' 'Ferndale' 'Lopez Island' 'Hoquiam' 'Newport'
#  'Spangle' 'Stevenson' 'Buckley' 'Point Roberts' 'Rosalia' 'Taholah'
#  'Blaine' 'Montesano' 'Graham' 'Lakebay' 'Underwood' 'Chehalis'
#  'Clarkston' 'Union' 'Fox Island' 'La Conner' 'Rock Island'
#  'West Richland' 'Aberdeen' 'Parkland' 'Pacific Beach' 'Liberty Lake'
#  'Medical Lake' 'Benton City' 'Newman Lake' 'Grapeview' 'Spanaway'
#  'Dupont' 'Sedro-Woolley' 'Naselle' 'Husum' 'Sumas' 'Quincy' 'Endicott'
#  'Murdock' 'Winlock' 'Mica' 'Omaha' 'Winthrop' 'Greenacres' 'Norristown'
#  'Packwood' 'Bow' 'Greenbank' 'Toledo' 'Lummi Island' 'Long Beach'
#  'Steilacoom' 'Mead' 'Morton' 'Tempe' 'Twisp' 'Ilwaco' 'Easton' 'Westport'
#  'Chattaroy' 'Airway Heights' 'Oroville' 'Lopez Is' 'Lake Tapps'
#  'Neah Bay' 'Onalaska' 'Highland Park' 'Peshastin' 'North Bonneville'
#  'Colbert' 'Evans' 'Fairchild Air Force Base' 'Lind' 'Cathlamet'
#  'Clallam Bay' 'Frances' 'Elk' 'Othello' 'Clearlake' 'Washington'
#  'Raymond' 'Okanogan' 'Reardan' 'Mossyrock' 'Mesa' 'Seaview' 'Ephrata'
#  'Silver Creek' 'Ritzville' 'Mineral' 'Roy' 'Everson' 'Burbank'
#  'Annapolis' 'Henrico' 'Lilliwaup' 'Glacier' 'Harrington' 'Tahuya'
#  'Cashmere' 'Garfield' 'Outlook' 'Las Vegas' 'Buena Park' 'Wilbur'
#  'Ronald' 'Sekiu' 'Roslyn' 'Cosmopolis' 'Mattawa' 'Ocean Park' 'Ashford'
#  'Tonasket' 'Salkum' 'Maple Falls' 'Riverside' 'Ethel' 'Dayton' 'Colfax'
#  'Lamont' 'Hatton' 'Ridgecrest' 'Mazama' 'Shaw Island' 'Brewster'
#  'Kittitas' 'San Rafael' 'Vaughn' 'Usk' 'Waitsburg' 'Asotin' 'Grayland'
#  'Bz Corner' 'South Prairie' 'Vantage' 'Eltopia' 'University Place'
#  'Salem' 'Otis Orchards' 'Carbonado' 'Soap Lake' 'Bay Center' 'Satsop'
#  'Hartline' 'Carlton' 'Curlew' 'Snoqualmie Pass' 'Rockport' 'San Antonio'
#  'Glenoma' 'Nooksack' 'Raeford' 'Vader' 'Libertyville' 'Cheyenne'
#  'Seven Bays' 'Malaga' 'Kapowsin' 'Addy' 'Pittsburg' 'Prescott'
#  'Electric City' 'Touchet' 'Smiths Station' 'Hamilton' 'Orcas Is'
#  'Uniontown' 'Marlin' 'Waterville' 'Decatur' 'Republic' 'Rockford'
#  'Connell' 'Rosburg' 'Menlo' 'Acme' 'Waldron' 'Platte City' 'Lebam'
#  'Latah' 'Rice' 'Roosevelt' 'Fort Bragg' 'Beaver' 'Pomeroy' 'Aldie'
#  'San Diego' 'Oakville' 'Longbranch' 'Skamokawa' 'Greenfield Center'
#  'Wilkeson' 'Curtis' 'Gardena' 'Copalis Crossing' 'Gambrills' 'Wishram'
#  'Cinebar' 'Santa Cruz' 'Warden' 'Grays River' 'El Paso' 'Cusick'
#  'Oceanside' 'Bridgeport Bar' 'Coulee City' 'Santa Clara' 'Stratford'
#  'Silver Spring' 'Little Elm' 'Frederick' 'Goldsboro' 'North Cove'
#  'Edwall' 'Wildomar' 'Valley' 'Dallesport' 'Ravensdale' 'Cowiche'
#  'Glenwood' 'Davenport' 'Preston' 'Edgewater' 'Lyle' 'Loon Lake' 'Custer'
#  'Concrete' 'Chinook' 'Oysterville' 'Tokeland' 'Springfield' 'Danville'
#  'Ruston' 'Hunters' 'Portland' 'Sacramento' 'Pe Ell' 'Lincoln'
#  'Silver Lake' 'Westminster' 'Moclips' 'Wichita Falls' 'Surfside'
#  'Nahcotta' 'Deming' 'Pateros']

# %%
print(df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].unique())
print('\n')

print(df['Electric Vehicle Type'].unique())
print('\n')

print(df['Electric Utility'].unique())
# Out:
# ['Clean Alternative Fuel Vehicle Eligible'
#  'Not eligible due to low battery range'
#  'Eligibility unknown as battery range has not been researched']
#
#
# ['Battery Electric Vehicle (BEV)' 'Plug-in Hybrid Electric Vehicle (PHEV)']
#
#
# ['PACIFICORP' 'PUGET SOUND ENERGY INC'
#  'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)'
#  'PUD NO 1 OF CHELAN COUNTY' 'MODERN ELECTRIC WATER COMPANY' 'AVISTA CORP'
#  'PUD NO 1 OF DOUGLAS COUNTY' 'CITY OF CHENEY - (WA)'
#  'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)' nan
#  'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)'
#  'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF KLICKITAT COUNTY'
#  'BONNEVILLE POWER ADMINISTRATION||PUD 1 OF SNOHOMISH COUNTY'
#  'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF COWLITZ COUNTY'
#  'BONNEVILLE POWER ADMINISTRATION||PUGET SOUND ENERGY INC||PUD NO 1 OF JEFFERSON COUNTY'
#  'BONNEVILLE POWER ADMINISTRATION||PACIFICORP||PUD NO 1 OF CLARK COUNTY - (WA)'
#  'NO KNOWN ELECTRIC UTILITY SERVICE'
#  'BONNEVILLE POWER ADMINISTRATION||PACIFICORP||BENTON RURAL ELECTRIC ASSN'
#  'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF MASON COUNTY|PUD NO 1 OF JEFFERSON COUNTY'
#  'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLALLAM COUNTY'
#  'CITY OF TACOMA - (WA)'
#  'BONNEVILLE POWER ADMINISTRATION||CITY OF PORT ANGELES - (WA)'
#  'BONNEVILLE POWER ADMINISTRATION||BENTON RURAL ELECTRIC ASSN'
#  'BONNEVILLE POWER ADMINISTRATION||CITY OF MILTON - (WA)|CITY OF TACOMA - (WA)'
#  'CITY OF CHEWELAH'
#  'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||PENINSULA LIGHT COMPANY'
#  'CITY OF TACOMA - (WA)||TANNER ELECTRIC COOP' 'CITY OF SEATTLE - (WA)'
#  'BONNEVILLE POWER ADMINISTRATION||AVISTA CORP||INLAND POWER & LIGHT COMPANY'
#  'PUGET SOUND ENERGY INC||PUD NO 1 OF WHATCOM COUNTY'
#  'BONNEVILLE POWER ADMINISTRATION||ORCAS POWER & LIGHT COOP'
#  'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||PUD NO 3 OF MASON COUNTY'
#  'PUD NO 1 OF OKANOGAN COUNTY' 'PUD NO 2 OF GRANT COUNTY'
#  'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||PARKLAND LIGHT & WATER COMPANY|PENINSULA LIGHT COMPANY'
#  'BONNEVILLE POWER ADMINISTRATION||CITY OF RICHLAND - (WA)'
#  'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF FRANKLIN COUNTY'
#  'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF BENTON COUNTY'
#  'BONNEVILLE POWER ADMINISTRATION||VERA IRRIGATION DISTRICT #15'
#  'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF GRAYS HARBOR COUNTY'
#  'BONNEVILLE POWER ADMINISTRATION||CITY OF CENTRALIA - (WA)|CITY OF TACOMA - (WA)'
#  'NON WASHINGTON STATE ELECTRIC UTILITY'
#  'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||ELMHURST MUTUAL POWER & LIGHT CO|PENINSULA LIGHT COMPANY'
#  'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||LAKEVIEW LIGHT & POWER|PENINSULA LIGHT COMPANY'
#  'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF SKAMANIA CO'
#  'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||OHOP MUTUAL LIGHT COMPANY, INC|PENINSULA LIGHT COMPANY'
#  'BONNEVILLE POWER ADMINISTRATION||INLAND POWER & LIGHT COMPANY'
#  'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||PUD NO 1 OF LEWIS COUNTY'
#  'PUD NO 1 OF PEND OREILLE COUNTY'
#  'BONNEVILLE POWER ADMINISTRATION||CITY OF ELLENSBURG - (WA)'
#  'CITY OF BLAINE - (WA)||PUD NO 1 OF WHATCOM COUNTY'
#  'BONNEVILLE POWER ADMINISTRATION||AVISTA CORP||PUD NO 1 OF ASOTIN COUNTY'
#  'BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF PACIFIC COUNTY'
#  'CITY OF SUMAS - (WA)||PUD NO 1 OF WHATCOM COUNTY'
#  'OKANOGAN COUNTY ELEC COOP, INC'
#  'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF KITTITAS COUNTY'
#  'PUD NO 1 OF WHATCOM COUNTY'
#  'BONNEVILLE POWER ADMINISTRATION||TOWN OF STEILACOOM|CITY OF TACOMA - (WA)||PENINSULA LIGHT COMPANY'
#  'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF WAHKIAKUM COUNTY'
#  'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||PUD NO 1 OF MASON COUNTY'
#  'BONNEVILLE POWER ADMINISTRATION||AVISTA CORP||BIG BEND ELECTRIC COOP, INC'
#  'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||BENTON RURAL ELECTRIC ASSN|PENINSULA LIGHT COMPANY'
#  'BONNEVILLE POWER ADMINISTRATION||BIG BEND ELECTRIC COOP, INC'
#  'BONNEVILLE POWER ADMINISTRATION||TOWN OF EATONVILLE - (WA)|CITY OF TACOMA - (WA)'
#  'BONNEVILLE POWER ADMINISTRATION||COLUMBIA RURAL ELEC ASSN, INC'
#  'BONNEVILLE POWER ADMINISTRATION||PACIFICORP||COLUMBIA RURAL ELEC ASSN, INC'
#  'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||ALDER MUTUAL LIGHT CO, INC|PENINSULA LIGHT COMPANY'
#  'PORTLAND GENERAL ELECTRIC CO'
#  'BONNEVILLE POWER ADMINISTRATION||CITY OF MCCLEARY - (WA)'
#  'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF FERRY COUNTY'
#  'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF ASOTIN COUNTY'
#  'BONNEVILLE POWER ADMINISTRATION||PENINSULA LIGHT COMPANY'
#  'BONNEVILLE POWER ADMINISTRATION||TOWN OF RUSTON - (WA)|CITY OF TACOMA - (WA)||PENINSULA LIGHT COMPANY'
#  'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF ASOTIN COUNTY||INLAND POWER & LIGHT COMPANY']

# %%
print(df['Base MSRP'].unique()) # no se lo que es
print('\n')

print(df['Electric Range'].unique()) # autonomia eléctrica en km
print('\n')

print(df['Vehicle Location'].nunique())
print(df['Postal Code'].nunique())
# Out:
# [     0  69900  32250  59900  31950  54950  52900  36800  81100  39995
#   36900  98950  33950 110950  45600  44100  64950  53400  55700  34995
#   43700  52650  90700 184400 102000  91250 109000 845000  75095  32995
#   89100]
#
#
# [238  47 220  75 210  19  23 208  84   0 308 322  20  26  38 266  35 107
#   58  73 151  14 291 215  32 259  25  72 149 200  21  82 150  30  87 330
#   18  53 239 100  93  16 270 293 249  29  37  33   6  40  17  22  68 125
#  265  83 192 204 289   8 153  27  42  34  97 222  13 126 258  12  76  81
#   10  41 234 233 111 103  15 114 245 110 337  28 203  62 124 218  48 170
#   31  24   9  11  56  95  51  57  36  59  74]
#
#
# 539
# 545

# %%
df.describe()
# Out:
#         Postal Code     Model Year  Electric Range      Base MSRP
# count  99998.000000  100000.000000   100000.000000  100000.000000  \
# mean   98202.893398    2019.569420       77.642780    1480.081600
# std     1154.436697       2.969628       99.808182    9857.045112
# min    12833.000000    1998.000000        0.000000       0.000000
# 25%    98042.000000    2018.000000        0.000000       0.000000
# 50%    98115.000000    2020.000000       25.000000       0.000000
# 75%    98296.000000    2022.000000      151.000000       0.000000
# max    99403.000000    2023.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count          99941.000000    1.000000e+05       9.999800e+04
# mean              30.764191    2.055639e+08       5.302110e+10
# std               14.669756    8.807642e+07       8.125962e+08
# min                1.000000    4.385000e+03       1.081042e+09
# 25%               20.000000    1.567694e+08       5.303301e+10
# 50%               35.000000    2.034921e+08       5.303303e+10
# 75%               43.000000    2.294392e+08       5.303509e+10
# max               49.000000    4.789346e+08       5.602100e+10

# %%
df.sample(3)
# Out:
#        VIN (1-10)  County       City State  Postal Code  Model Year    Make
# 32290  1N4AZ0CP8E    King    Seattle    WA      98117.0        2014  NISSAN  \
# 88881  1N4BZ0CP9H  Pierce    Buckley    WA      98321.0        2017  NISSAN
# 46622  JTDKN3DP7F   Clark  Washougal    WA      98671.0        2015  TOYOTA
#
#                Model                   Electric Vehicle Type
# 32290           LEAF          Battery Electric Vehicle (BEV)  \
# 88881           LEAF          Battery Electric Vehicle (BEV)
# 46622  PRIUS PLUG-IN  Plug-in Hybrid Electric Vehicle (PHEV)
#
#       Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range
# 32290           Clean Alternative Fuel Vehicle Eligible              84  \
# 88881           Clean Alternative Fuel Vehicle Eligible             107
# 46622             Not eligible due to low battery range               6
#
#        Base MSRP  Legislative District  DOL Vehicle ID
# 32290          0                  36.0       170592523  \
# 88881          0                  31.0       183414458
# 46622          0                  18.0       185344218
#
#                   Vehicle Location
# 32290  POINT (-122.38418 47.70044)  \
# 88881  POINT (-122.02523 47.16299)
# 46622  POINT (-122.35341 45.57923)
#
#                                         Electric Utility  2020 Census Tract
# 32290       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 88881      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.305307e+10
# 46622  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...       5.301104e+10

# %% [markdown]
# ## Limpieza y manipulacion de datos
#
# ### Selección de columnas
#
# No todas las columnas son interesantes

# %%
col_deseadas = ['County',
                'City',
                'Model Year',
                'Make', 
                'Model',
                'Electric Vehicle Type', 
                'Clean Alternative Fuel Vehicle (CAFV) Eligibility',
                'Electric Range',
                'DOL Vehicle ID',
                'Vehicle Location',
                'Electric Utility' ]

df = df[col_deseadas]
display(df.head())
# Out:
#      County     City  Model Year    Make    Model
# 0    Yakima   Yakima        2018   TESLA  MODEL X  \
# 1    Kitsap  Poulsbo        2021   HONDA  CLARITY
# 2      King  Seattle        2019   TESLA  MODEL 3
# 3      King  Seattle        2013  NISSAN     LEAF
# 4  Thurston    Lacey        2017   TESLA  MODEL S
#
#                     Electric Vehicle Type
# 0          Battery Electric Vehicle (BEV)  \
# 1  Plug-in Hybrid Electric Vehicle (PHEV)
# 2          Battery Electric Vehicle (BEV)
# 3          Battery Electric Vehicle (BEV)
# 4          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range
# 0           Clean Alternative Fuel Vehicle Eligible             238  \
# 1           Clean Alternative Fuel Vehicle Eligible              47
# 2           Clean Alternative Fuel Vehicle Eligible             220
# 3           Clean Alternative Fuel Vehicle Eligible              75
# 4           Clean Alternative Fuel Vehicle Eligible             210
#
#    DOL Vehicle ID             Vehicle Location
# 0       141151601  POINT (-120.56916 46.58514)  \
# 1       171566447  POINT (-122.64681 47.73689)
# 2         9426525  POINT (-122.40092 47.65908)
# 3       211807760   POINT (-122.3684 47.64586)
# 4       185810306  POINT (-122.75379 47.06316)
#
#                                Electric Utility
# 0                                    PACIFICORP
# 1                        PUGET SOUND ENERGY INC
# 2  CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 3  CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 4                        PUGET SOUND ENERGY INC

# %% [markdown]
# ### Hay duplicados ?

# %%
df.duplicated().any() # no
# Out:
# False

# %% [markdown]
# ### Hay outliers?

# %%
df.describe()
# Out:
#           Model Year  Electric Range  DOL Vehicle ID
# count  100000.000000   100000.000000    1.000000e+05
# mean     2019.569420       77.642780    2.055639e+08
# std         2.969628       99.808182    8.807642e+07
# min      1998.000000        0.000000    4.385000e+03
# 25%      2018.000000        0.000000    1.567694e+08
# 50%      2020.000000       25.000000    2.034921e+08
# 75%      2022.000000      151.000000    2.294392e+08
# max      2023.000000      337.000000    4.789346e+08

# %% [markdown]
# Parece que hay vehiculos con autonomía 0

# %%
mask = df['Electric Range'] == 0

len(df[mask])
# Out:
# 40868

# %% [markdown]
# Hay demasiados vehículos con autonomía 0, y eso no tiene sentido, por lo que voy a imponer el valor del más frecuente

# %%
df.loc[mask,'Electric Range'] = np.nan # antes de aplicar el imputer los valores 0 seran nan

# %%
from sklearn.impute import SimpleImputer

# %%
most_common_imputer = SimpleImputer(strategy='median') # voy a imponer el de la mediana
df_numeric = df.select_dtypes(include=np.number)
most_common_imputer.fit(df_numeric)
# Out:
# SimpleImputer(strategy='median')

# %%
array_numeric = most_common_imputer.transform(df_numeric)

# %%
df_numeric = pd.DataFrame(array_numeric, columns = df_numeric.columns, index=df_numeric.index )
df_numeric.isna().any()
# Out:
# Model Year        False
# Electric Range    False
# DOL Vehicle ID    False
# dtype: bool

# %%
df['Model Year'] = df_numeric['Model Year']
df['Electric Range'] = df_numeric['Electric Range']
df['DOL Vehicle ID'] = df_numeric['DOL Vehicle ID']

# %% [markdown]
# ### Nans

# %%
df.isna().any().count()
# Out:
# 11

# %% [markdown]
# Solo hay 11 Nans, no es ni el 0,1% del dataset por  lo  que los voy a borrar

# %%
df.dropna(axis= 0, inplace= True)

# %%
df.info() # ya no hay ningun Nan
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99806 entries, 0 to 99999
# Data columns (total 11 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   County                                             99806 non-null  object
#  1   City                                               99806 non-null  object
#  2   Model Year                                         99806 non-null  float64
#  3   Make                                               99806 non-null  object
#  4   Model                                              99806 non-null  object
#  5   Electric Vehicle Type                              99806 non-null  object
#  6   Clean Alternative Fuel Vehicle (CAFV) Eligibility  99806 non-null  object
#  7   Electric Range                                     99806 non-null  float64
#  8   DOL Vehicle ID                                     99806 non-null  float64
#  9   Vehicle Location                                   99806 non-null  object
#  10  Electric Utility                                   99806 non-null  object
# dtypes: float64(3), object(8)
# memory usage: 9.1+ MB

# %% [markdown]
# ### arreglar datos estructurales: longitud y latitud
#
# voy a separ la longitud y latitud en diferentes columnas y pasarlos a tipo númerico que es lo que son

# %%
df['Vehicle Location']= df['Vehicle Location'].str.replace('POINT (','')
df['Vehicle Location']= df['Vehicle Location'].str.replace(')','')


df['Vehicle Location']= df['Vehicle Location'].str.split(' ')
df['Vehicle Location'].head()
# Out:
# 0    [-120.56916, 46.58514]
# 1    [-122.64681, 47.73689]
# 2    [-122.40092, 47.65908]
# 3     [-122.3684, 47.64586]
# 4    [-122.75379, 47.06316]
# Name: Vehicle Location, dtype: object

# %%
def separar_cordenadas(fila): # para separar la latitud y la londitud 
    longitud = round(float(fila[0]), 4)
    latitud = round(float(fila[1]), 4)
    return pd.Series([longitud, latitud])

# %%
df[['longitud', 'latitud']] = df['Vehicle Location'].apply(lambda x: separar_cordenadas(x))

# %%
df.drop(axis=1, columns='Vehicle Location', inplace=True)

# %%
df.dtypes
# Out:
# County                                                object
# City                                                  object
# Model Year                                           float64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                       float64
# DOL Vehicle ID                                       float64
# Electric Utility                                      object
# longitud                                             float64
# latitud                                              float64
# dtype: object

# %% [markdown]
# #### El año y el ID del vehiculo han pasado a tipo float
#
# Probablemente cuando le hemos pasado el imputer

# %%
df['Model Year'] = df['Model Year'].astype('int64')
df['DOL Vehicle ID'] = df['DOL Vehicle ID'].astype(int)
df.dtypes
# Out:
# County                                                object
# City                                                  object
# Model Year                                             int64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                       float64
# DOL Vehicle ID                                         int32
# Electric Utility                                      object
# longitud                                             float64
# latitud                                              float64
# dtype: object

# %% [markdown]
# ## EDA: Análisis exploratorio de los datos

# %%
df.sample(5)
# Out:
#          County        City  Model Year    Make      Model
# 38363     Clark   Vancouver        2019  SUBARU  CROSSTREK  \
# 11889     Clark   Washougal        2023    MINI    HARDTOP
# 14728  Thurston     Olympia        2023  NISSAN      ARIYA
# 30691      King  Des Moines        2022    FORD     ESCAPE
# 41813      King   Sammamish        2018    AUDI         A3
#
#                         Electric Vehicle Type
# 38363  Plug-in Hybrid Electric Vehicle (PHEV)  \
# 11889          Battery Electric Vehicle (BEV)
# 14728          Battery Electric Vehicle (BEV)
# 30691  Plug-in Hybrid Electric Vehicle (PHEV)
# 41813  Plug-in Hybrid Electric Vehicle (PHEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range
# 38363              Not eligible due to low battery range            17.0  \
# 11889  Eligibility unknown as battery range has not b...            87.0
# 14728  Eligibility unknown as battery range has not b...            87.0
# 30691            Clean Alternative Fuel Vehicle Eligible            38.0
# 41813              Not eligible due to low battery range            16.0
#
#        DOL Vehicle ID                                   Electric Utility
# 38363         1928258  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...  \
# 11889       213611884  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...
# 14728       235992676                             PUGET SOUND ENERGY INC
# 30691       192390607      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 41813       167264800      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
#
#        longitud  latitud
# 38363 -122.5476  45.6283
# 11889 -122.3534  45.5792
# 14728 -122.8917  47.0396
# 30691 -122.2959  47.4014
# 41813 -122.0205  47.6033

# %% [markdown]
#  ### ¿Cual es el primer coche eléctrico que se registro en en todo el dataset? ¿Cual es su marca, ciudad, modelo, y que autonomía tenía?

# %%
cond = df['Model Year'] == df['Model Year'].min()

primer_EV_en_WA = df.loc[cond,['Model Year', 'Make', 'Model', 'City', 'Electric Range']]
primer_EV_en_WA
# Out:
#        Model Year  Make   Model    City  Electric Range
# 28188        1998  FORD  RANGER  Sequim            58.0

# %%
primer_EV_en_WA['Model Year']
# Out:
# 28188    1998
# Name: Model Year, dtype: int64

# %% [markdown]
# #### Conclusiones

# %% [markdown]
# El primer coche eléctrico en WA era un ford modelo Ranger en la ciudad de Sequim con una autonomía de 58 km, en el año 1998

# %% [markdown]
# ### ¿En que año se trajo el primer Tesla a WA?

# %%
cond = df['Make'] == 'TESLA'

df_tesla = df.loc[cond, ['Model Year', 'Make', 'Model', 'City', 'Electric Range']]

cond_ = df_tesla['Model Year'] == df_tesla['Model Year'].min()
df_tesla[cond_]
# Out:
#        Model Year   Make     Model           City  Electric Range
# 893          2008  TESLA  ROADSTER       Kirkland           220.0
# 1526         2008  TESLA  ROADSTER   Port Orchard           220.0
# 13358        2008  TESLA  ROADSTER        Seattle           220.0
# 15253        2008  TESLA  ROADSTER         Burien           220.0
# 19737        2008  TESLA  ROADSTER        Seattle           220.0
# 25572        2008  TESLA  ROADSTER        Seattle           220.0
# 40023        2008  TESLA  ROADSTER        Redmond           220.0
# 48134        2008  TESLA  ROADSTER       Issaquah           220.0
# 51135        2008  TESLA  ROADSTER        Seattle           220.0
# 51167        2008  TESLA  ROADSTER        Seattle           220.0
# 51626        2008  TESLA  ROADSTER        Seattle           220.0
# 52055        2008  TESLA  ROADSTER       Kingston           220.0
# 52846        2008  TESLA  ROADSTER        Seattle           220.0
# 72938        2008  TESLA  ROADSTER       Bellevue           220.0
# 85308        2008  TESLA  ROADSTER     Gig Harbor           220.0
# 86492        2008  TESLA  ROADSTER  Friday Harbor           220.0

# %% [markdown]
# #### Conclusiones
#
# El primer modélo de tesla fue un Roadster, aparecieron varios en diferentes ciudades, y gozaban de una autonomía de nada más y nada menos que de 220 km.

# %% [markdown]
# ### ¿ Cuales son los 10 modelos más populares ?

# %%
df['Model'].value_counts().head(10)
# Out:
# Model
# MODEL 3        19627
# MODEL Y        17073
# LEAF           10164
# MODEL S         5689
# BOLT EV         4085
# MODEL X         3761
# VOLT            3397
# NIRO            1951
# PRIUS PRIME     1860
# ID.4            1802
# Name: count, dtype: int64

# %%
df['Model'].value_counts().head(10).plot(kind= 'bar',
                                         figsize= (10,6),
                                         color = ['grey', 'purple','orange', 'blue','green', 'yellow', 'black'],
                                         rot = 10,
                                         )

plt.title('Modelos de vehiculos electricos más poplares', fontdict={'fontsize':16})
plt.xlabel('MODELOS', fontdict={'fontsize':14})

plt.show()

# %%
cond1 = df['Model'] == 'MODEL 3'
cond2 = df['Model'] == 'MODEL Y'
cond3 = df['Model'] == 'LEAF'


df.loc[cond1 | cond2 | cond3, 'Make'].unique()
# Out:
# array(['TESLA', 'NISSAN'], dtype=object)

# %% [markdown]
# #### Conclusiones
#
# Los tres modelos más populares de coches eléctricos son MODEL3, MODEL Y, y LEAF perteneciendo los primeros dos a  la marca Tesla, y el último a Nissan.

# %% [markdown]
# ### ¿ Ha mejorado la autonomía de los coches con el paso de los años? ¿Hay alguna marca de vehículos que destaque sobre las demás en cuanto a autonomía se refiere?
#
# **Disclaimer**: El dato de autonomía de vehículo no era de buena calidad, y ha sido manipulado para tener unos datos más realistas, por lo que las conclusiones de este análisis no se deben tomar como verídicos.

# %%
Er_per_year = df.groupby(['Model Year'])['Electric Range'].mean()
Er_per_year
# Out:
# Model Year
# 1998     58.000000
# 1999     74.000000
# 2000     58.000000
# 2002     95.000000
# 2008    220.000000
# 2010    227.941176
# 2011     70.886513
# 2012     62.969943
# 2013     81.996155
# 2014     81.983514
# 2015     98.244059
# 2016    102.512368
# 2017    113.187289
# 2018    157.834014
# 2019    177.428836
# 2020    241.289787
# 2021     78.434835
# 2022     78.601610
# 2023     76.428468
# Name: Electric Range, dtype: float64

# %%
sns.lineplot(data= Er_per_year,
             x = Er_per_year.index,
             y = Er_per_year.values,
             )
sns.set(rc = {'figure.figsize':(15, 8)})
plt.title('Promedio de la autonomia eléctrica de los vehiculos electricos', fontdict={'fontsize':16})
plt.xlabel('Model Year', fontdict={'fontsize':14})
plt.show()

# %%
df['Make'].nunique()
# Out:
# 35

# %%
g = sns.lineplot(data= df,
             x= 'Model Year',
             y = 'Electric Range',
             hue= 'Make',
             )

sns.move_legend(g, "upper left", bbox_to_anchor=(1, 1))
sns.set(rc = {'figure.figsize':(12, 9)})

plt.title('Autonomía eléctrica por años segun la marca de vehículo', fontdict={'fontsize':16})
plt.xlabel('Model Year', fontdict={'fontsize':14})
plt.xlabel('Electric Range', fontdict={'fontsize':14})

plt.show()

# %% [markdown]
# #### conclusiones
#
# Segun el primer gráfico, la autonomía de los coches no parece seguir una tendencia claramente alcista (ni bajista, más bien, parece un rango cíclico) conforme pasan los años.
#
# El objetivo del segundo gráfico, que de hecho, no es una buena visualización, es ver si una marca destaca sobre las demás en cuanto a autonomía se refiere... Tesla destaca bastante al principio, pero tampoco se puede apreciar ninguna tendencia clara, ni en Tesla ni en las demas marcas.

# %% [markdown]
# ### ¿Como se distribuyen los vehículos eléctricos en la ciudad de washinton geograficamente?

# %%
df.head()
# Out:
#      County     City  Model Year    Make    Model
# 0    Yakima   Yakima        2018   TESLA  MODEL X  \
# 1    Kitsap  Poulsbo        2021   HONDA  CLARITY
# 2      King  Seattle        2019   TESLA  MODEL 3
# 3      King  Seattle        2013  NISSAN     LEAF
# 4  Thurston    Lacey        2017   TESLA  MODEL S
#
#                     Electric Vehicle Type
# 0          Battery Electric Vehicle (BEV)  \
# 1  Plug-in Hybrid Electric Vehicle (PHEV)
# 2          Battery Electric Vehicle (BEV)
# 3          Battery Electric Vehicle (BEV)
# 4          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range
# 0           Clean Alternative Fuel Vehicle Eligible           238.0  \
# 1           Clean Alternative Fuel Vehicle Eligible            47.0
# 2           Clean Alternative Fuel Vehicle Eligible           220.0
# 3           Clean Alternative Fuel Vehicle Eligible            75.0
# 4           Clean Alternative Fuel Vehicle Eligible           210.0
#
#    DOL Vehicle ID                              Electric Utility  longitud
# 0       141151601                                    PACIFICORP -120.5692  \
# 1       171566447                        PUGET SOUND ENERGY INC -122.6468
# 2         9426525  CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA) -122.4009
# 3       211807760  CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA) -122.3684
# 4       185810306                        PUGET SOUND ENERGY INC -122.7538
#
#    latitud
# 0  46.5851
# 1  47.7369
# 2  47.6591
# 3  47.6459
# 4  47.0632

# %%
import matplotlib.colors as colors

# %%
vmin = df['Model Year'].max() - (df['Model Year'].max() - df['Model Year'].min()) * 0.3
vmax = df['Model Year'].max()

norm = colors.Normalize(vmin=vmin, vmax=vmax)

scatter = df.plot(kind="scatter", x="longitud", y="latitud", grid=True,
                  s=df["Electric Range"]/10, label="Demografia VE",
                  c="Model Year", cmap="jet", colorbar=True,
                  legend=True, sharex=False, figsize=(17,11), norm= norm)

axis = -125, -116.5, 45.2, 49.5
plt.axis(axis)

plt.title('Populación de VE en el estado de Washintong', fontdict={'fontsize':18})
plt.ylabel('Latitud', fontdict={'fontsize':14})
plt.xlabel('Longitud', fontdict={'fontsize':14})

ruta_img = os.path.join('img','WA_state_2.png')
california_img = plt.imread(ruta_img)
plt.imshow(california_img, extent=axis)

plt.show()
