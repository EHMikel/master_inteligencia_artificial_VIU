# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Master' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Master' 'Secundaria' 'Grado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Doctorado' 'Bachillerato'
#  'Bachillerato' 'Master' 'Doctorado' 'Master' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato' 'Secundaria' 'Grado'
#  'Bachillerato' 'Grado' 'Master' 'Master' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Doctorado' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Doctorado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Master' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Master' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Grado' 'Master' 'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Grado'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Secundaria' 'Secundaria' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato'
#  'Grado' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Master' 'Grado'
#  'Grado' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Master' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Master' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Master' 'Secundaria' 'Secundaria' 'Master' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Master' 'Bachillerato' 'Master' 'Grado' 'Grado' 'Secundaria'
#  'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Master' 'Secundaria' 'Bachillerato' 'Master' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Master'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Doctorado' 'Master' 'Master' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Secundaria' 'Master' 'Master' 'Bachillerato'
#  'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Master' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado'
#  'Grado' 'Master' 'Secundaria' 'Secundaria' 'Grado' 'Master' 'Doctorado'
#  'Secundaria' 'Master' 'Bachillerato' 'Bachillerato' 'Grado' 'Master'
#  'Master' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Master'
#  'Bachillerato' 'Master' 'Grado' 'Master' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master'
#  'Grado' 'Grado' 'Doctorado' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Master' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria' 'Grado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Master'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Bachillerato'
#  'Master' 'Grado' 'Grado' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Doctorado' 'Grado' 'Doctorado' 'Bachillerato' 'Grado'
#  'Grado' 'Grado' 'Master' 'Bachillerato' 'Secundaria' 'Grado' 'Master'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Master' 'Grado'
#  'Grado' 'Secundaria' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Doctorado' 'Master' 'Grado' 'Grado' 'Secundaria'
#  'Doctorado' 'Secundaria' 'Secundaria' 'Master' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Doctorado' 'Grado' 'Master' 'Bachillerato'
#  'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Grado' 'Secundaria' 'Doctorado' 'Grado' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Master' 'Grado' 'Grado' 'Grado' 'Grado' 'Secundaria'
#  'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Bachillerato'
#  'Master' 'Secundaria' 'Master' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Master'
#  'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Secundaria' 'Doctorado'
#  'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Doctorado'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Grado' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Master' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Doctorado' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Grado' 'Grado' 'Bachillerato' 'Master' 'Grado' 'Bachillerato'
#  'Master' 'Grado' 'Grado' 'Master' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Doctorado' 'Doctorado' 'Doctorado' 'Grado'
#  'Bachillerato' 'Doctorado' 'Grado' 'Master']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()
